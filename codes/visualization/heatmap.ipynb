# %%
"""
ヒートマップ
"""
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import japanize_matplotlib


# %matplotlib inline
plt.style.use('bmh') # matplotlib のスタイルの設定

df = pd.read_csv('../../data/dummy_data/auto-mpg.csv')

# ヒートマップ
# NOTE: annot: セルに値を表示するかどうか
# NOTE: cmap: カラーマップ。色を指定できる。
sns.heatmap(df.corr(), annot=True, cmap='Blues', vmax=1, vmin=-1, center=0, fmt='.2f')
# Out:
# /tmp/ipykernel_20427/1794726196.py:18: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='Blues', vmax=1, vmin=-1, center=0, fmt='.2f')
# <Axes: >
